# %%
import load
import text_preprocess

# %%
preprocess = text_preprocess.Preprocess("/Users/jylee/Desktop/GeniA_project/Topic_Modeling/Data/transcripts.csv")

# %%
texts, dictionary, corpus = preprocess.get_input_sets()
# Out:
# ...
#   0%|          | 0/302 [00:00<?, ?it/s]

# %%
corpus
# Out:
# [[(0, 1), (1, 1)],
#  [(2, 1)],
#  [(3, 1), (4, 1), (5, 1)],
#  [(3, 1), (4, 2), (6, 1), (7, 1)],
#  [(7, 1)],
#  [(3, 1), (4, 1), (5, 1)],
#  [(8, 2), (9, 1), (10, 1)],
#  [(3, 1), (5, 1), (6, 1), (7, 1), (11, 1)],
#  [(11, 1)],
#  [(0, 2), (1, 1), (12, 2)],
#  [(0, 1), (1, 1), (2, 1), (6, 4), (7, 1), (11, 2)],
#  [(1, 1), (9, 1), (10, 1)],
#  [(12, 1)],
#  [(0, 2), (1, 2), (5, 1), (11, 1)],
#  [(13, 1)],
#  [(0, 1), (1, 1), (11, 1)],
#  [],
#  [(0, 1), (1, 1), (6, 1), (11, 1)],
#  [(6, 1)],
#  [(5, 1), (6, 1)],
#  [(6, 1)],
#  [],
#  [],
#  [(5, 1)],
#  [],
#  [(6, 1), (11, 1)],
#  [],
#  [(5, 1), (6, 1)],
#  [(2, 1), (5, 1), (11, 1), (12, 2)],
#  [(0, 1), (12, 1)],
#  [(0, 1), (11, 2)],
#  [(5, 1)],
#  [(11, 1)],
#  [(2, 1)],
#  [(0, 2), (1, 2), (2, 1), (12, 2)],
#  [(13, 1)],
#  [(1, 1)],
#  [(0, 1), (1, 1), (2, 1), (5, 1), (11, 1)],
#  [(2, 1), (13, 1)],
#  [(0, 1), (1, 1), (5, 1), (8, 1)],
#  [(12, 1)],
#  [(0, 1), (1, 1), (5, 1)],
#  [(1, 1), (14, 1)],
#  [(1, 1), (14, 1)],
# ...

# %%
dataframe = load.load_data(file_nm="/Users/jylee/Desktop/GeniA_project/Topic_Modeling/Data/transcripts.csv")

# %%
load.get_cleaned(dataframe)
# Out:
# [Kss]: Oh! You have konlpy.tag.Mecab in your environment. Kss will take this as a backend! :D
#   0%|          | 0/302 [00:00<?, ?it/s]
# ['이번 시간에는 인수 분해에 대해서 알아보도록 하겠습니다',
#  '자 2인 수분의 는 요',
#  '우리가 앞서 배웠던 곱셈 공식과 아주 밀접한 관련이 있습니다',
#  '곱셈 공식 은 언제 필요하냐 하면 요 이 다항식 뜰의 곱을 1 전개하는데 필요했던 공식들이 얻죠',
#  '자 그렇다면 당시 게 곳들을 전개한다는 것이 이인수 분의 와 어떤 관련성이 있는지 같이 한번 살펴보겠습니다',
#  '우리 곱셈 공식 배우면서 이런 거 했던 기억이 있을 거예요',
#  '뭐냐면 x이라는 다음 식과 x이라는 다음 식을 고 파게 되면 어떻게 된다 x 제곱  3 x 플러스 2 가 된다',
#  '그래서 유 두 다항식의 곱셈을 하나의 당 식으로 표현할 수 있다나는 걸 배웠는데 그때 이쪽에서 일로 이렇게 넘어가는 과정을 우리가 전개한다',
#  '이렇게 표현을 했었습니다',
#  '기억나시죠',
#  '자 그렇다면 일쑤 분해라는 건 뭘 얘기하냐면 요 예 이쪽에서 1루 넘어오는 과정을 인수분해라고 얘기를 합니다',
#  '그래서 이 둘의 차이점은 뭐냐면 전개 나는 것은 두 개 이상의 다항식 을 곱해서 하나의 다항식으로 표현하는 거고요 인수분해라는 것은 하나의 다항식을 2개 이상의 다항식에 곱으로 표현하는 게 바로 인수분해 해요',
#  '이때 이 당시 x  1과 x  이를 요 뭐라고 부르냐 하면 이우 변에 있는 방식 x 제곱  3 x 플러스 e에 인수 들이다',
#  '이렇게 얘기를 합니다',
#  '따라서 하나의 당시 글 1 인수 들로 분해하여 그것들의 곱으로 표현했다는 의미로 우리가 이름을 인수분해라고 붙인 거예요',
#  '자 여기까지 말씀을 드리면 학생들이 질문을 합니다',
# ...
